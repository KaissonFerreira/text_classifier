# %% [markdown]
# # Objetivo Geral:
#
# **Construir um algoritmo que classifique os comentários calculando a probabilidade de se recomendar o produto para algum(a) amigo(a)**

# %% [markdown]
# # 0.0 Imports

# %%
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Data manipulation
import pandas as pd
import re

# Config path and dir
import pathlib
import os

# %% [markdown]
# ## 0.1 Data Loading

# %% [markdown]
# ### 0.1.1 Caminhos de diretórios e arquivos

# %%
#os.path.abspath('..')

# %%
BASE_DIR = pathlib.Path().resolve().parent.absolute()
DATA_DIR = os.path.join(BASE_DIR, 'data')
DATA_RAW_DIR = os.path.join(DATA_DIR, 'raw')
DATA_EXTERNAL_DIR = os.path.join(DATA_DIR, 'external')
DATA_INTERIM_DIR = os.path.join(DATA_DIR, 'interim')
DATA_PROCESSED_DIR = os.path.join(DATA_DIR, 'processed')
DATA_RAW_FILE = os.path.join(DATA_RAW_DIR, 'review.csv')

# %% [markdown]
# ### 0.1.2 Load

# %%
path = rf'{DATA_RAW_FILE}'
df = pd.read_csv(path)
# Out:
# C:\Users\kayss\AppData\Local\Temp\ipykernel_4188\3283744367.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %% [markdown]
# # 1.0 Data Description

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132373 entries, 0 to 132372
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   submission_date        132373 non-null  object
#  1   reviewer_id            132373 non-null  object
#  2   product_id             132373 non-null  object
#  3   product_name           132289 non-null  object
#  4   product_brand          40982 non-null   object
#  5   site_category_lv1      132367 non-null  object
#  6   site_category_lv2      128360 non-null  object
#  7   review_title           132071 non-null  object
#  8   overall_rating         132373 non-null  int64
#  9   recommend_to_a_friend  132355 non-null  object
#  10  review_text            129098 non-null  object
#  11  reviewer_birth_year    126389 non-null  float64
#  12  reviewer_gender        128237 non-null  object
#  13  reviewer_state         128382 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 14.1+ MB

# %%
df.tail()
# Out:
#             submission_date  \
# 132368  2018-05-31 23:30:50
# 132369  2018-05-31 23:42:25
# 132370  2018-05-31 23:44:16
# 132371  2018-05-31 23:46:48
# 132372  2018-05-31 23:50:33
#
#                                               reviewer_id product_id  \
# 132368  15f20e95ff44163f3175aaf67a5ae4a94d5030b409e521...   17962233
# 132369  def7cf9028b0673ab8bca3b1d06e085461fafb88cd48d9...  132631701
# 132370  7bcbf542f5d7dd9a9a192a6805adba7a7a4c1ce3bf00df...   16095859
# 132371  e6fb0b19277d01c2a300c7837a105f3c369377e92f9c19...    6774907
# 132372  ea9467aa73271fb4f68c04f4dd4f4eef304d6ee85441fb...  114081902
#
#                                              product_name product_brand  \
# 132368     Carregador De Pilha Sony + 4 Pilhas Aa 2500mah           NaN
# 132369          Mop Giratório Fit + Refil Extra - At Home           NaN
# 132370  Fita Led 5m Rgb 3528 Siliconada Com 300 Leds C...           NaN
# 132371       Etiquetas Jurídicas Vade Mecum - Marca Fácil   marca facil
# 132372  Painel de Fotos Bee Colection Rue Bac (74x94x3...         kapos
#
#             site_category_lv1                     site_category_lv2  \
# 132368   Câmeras e Filmadoras  Acessórios para Câmeras e Filmadoras
# 132369  Utilidades Domésticas                   Material de Limpeza
# 132370             Automotivo                            Iluminação
# 132371              Papelaria                Material de Escritório
# 132372              Decoração                       Painel de Fotos
#
#                 review_title  overall_rating recommend_to_a_friend  \
# 132368        Ótimo produto!               5                   Yes
# 132369           Sensacional               5                   Yes
# 132370         Ótimo produto               4                   Yes
# 132371  O produto não é bom.               1                    No
# 132372  Produto não entregue               1                    No
#
#                                               review_text  \
# 132368  Vale muito, estou usando no controle do Xbox e...
# 132369  Prático e barato, super indico o produto para ...
# 132370  Chegou antes do prazo previsto e corresponde a...
# 132371  Material fraco, poderia ser melhor. Ficou deve...
# 132372  Comprei esse produto, quando chegou estava com...
#
#         reviewer_birth_year reviewer_gender reviewer_state
# 132368               1988.0               M             RS
# 132369               1979.0               F             SP
# 132370               1979.0               F             PR
# 132371               1991.0               M             RJ
# 132372               1982.0               F             ES

# %% [markdown]
# **OBSERVAÇÕES:**
# - 14 Colunas: 2 Datas, 11 categóricas e 1 Númerica.
# - Há dados faltantes em algumas colunas, que dentre elas está o Review_text

# %% [markdown]
# # 2.0 Data Preparation

# %% [markdown]
# ## 2.1 Data Filtering

# %%
df_filtrado = df.loc[~df['review_text'].isnull()]
df_filtrado = df_filtrado.loc[~df_filtrado['recommend_to_a_friend'].isnull()]

# %%
# Confirmando se há o mesmo número de linhas para a recomendação e revisão de texto
df_filtrado[['recommend_to_a_friend','review_text']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129080 entries, 0 to 132372
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   recommend_to_a_friend  129080 non-null  object
#  1   review_text            129080 non-null  object
# dtypes: object(2)
# memory usage: 3.0+ MB

# %%
df_filtrado_2 = df_filtrado[['recommend_to_a_friend','review_text']]

# %% [markdown]
# ## 2.2 Aplicando funções de tratamento

# %%
# Verificando alguns exemplos de texto
df_filtrado_2['review_text'].tolist()
# Out:
# ['Estou contente com a compra entrega rápida o único problema com as Americanas é se houver troca ou devolução do produto o consumidor tem problemas com espera.',
#  'Por apenas R$1994.20,eu consegui comprar esse lindo copo de acrílico.',
#  'SUPERA EM AGILIDADE E PRATICIDADE OUTRAS PANELAS ELÉTRICAS.  COSTUMO USAR OUTRA PANELA PARA COZIMENTO DE ARROZ (JAPONESA), MAS LEVA MUITO TEMPO,  +/- 50 MINUTOS.  NESSA PANELA  É MUITO MAIS RÁPIDO, EXATAMENTE 6 MINUTOS.    EU RECOMENDO.',
#  'MEU FILHO AMOU! PARECE DE VERDADE COM TANTOS DETALHES QUE TÊM!',
#  'A entrega foi no prazo, as americanas estão de parabéns. A smart tv é muito boa, a navegação na internete e pelos aplicativos e excelente, não trava, sem falar da imagem que é de surpreender. recomendo.',
#  'Excelente produto, por fora em material acrílico super resistente e por dentro em adamantio, faz milagre com qualquer bebida. Sugiro aproveitarem a promoção antes que acabe.',
#  'produto mto bom, com essa garrafinha vc pode até servir água pro megazord. To pensando em vender minha tv pra comprar 1 garrafa dessa. RECOMENDO',
#  'Produto excelente qualidade boa câmera desenvolvimento do Android com rapidez',
#  'O barulho e minimo e o vento é bem forte na velocidade 2',
#  'MEU PRODUTO NAO FOI ENTREGUE E A AMERICANAS ESTA DESCONTANDO NA FATURA DO MEU CARTÃO',
#  'Comprei um pra cara membro da família nesse natal@!!!!',
#  'Produto maravilhoso! Não é barulhento, fácil manuseio, tranquilo de montar e desmontar, entrega antes do prazo mesmo se tratando de época do Natal. Americanas de parabéns e o produto muito bom. Recomendo com força.',
#  'Jogo de panelas excelente material, entrega a tempo, design muito bom.',
#  'Esse celular não vale nada a bateria não vale nada descarrega sozinha quando estar usando esquenta tanto que faz medo espludi foi a pior compra da minha vida se eu tivesse condições quebrava ele em mil pedaços e comprava outro de qualquer marca menos Motorola',
#  'produto de acordo com o que eu esperava. Somente o prazo de entrega que ficou um pouco a desejar, um pouco longo',
#  'a mochila nao esta fechando direito por isso nao recomendo se meu filho nao tivesse deixado suja ia devolver',
#  'Produto condizente com o anúncio, com material de boa qualidade, fácil instalação, montagem e preço de acordo com a necessidade de cada um...',
#  'nao tenho nada a reclamar, bom atendimento e entrega dentro do combinado.',
#  'Até agora os produtos que eu comprei foram entregue certo. Obrigado que continua assim.',
#  'A capa não decepcionou por enquanto, mas a bolsa para guarda ou transporte é extremamente frágil, na abertura para conferência já rasgou toda a volta junto ao fecho. Péssima impressão, terei que guarda-la noutra embalagem. Uma pena!!!!!',
#  'Produto ofereçe o que prometeu no anúncio, entrega muito rapida bem antes do prazo',
#  'Pontos Positivos Painel de 10bits (isso faz toda diferença da mais de 1 bilhão de cores) Bluetooth Wi-Fi AC USB 3.0 Input Lag Baixo Painel VA, que proporciona um alto contraste. Android TV 6.0 Som da TV realmente é excepcional! (saída do auto falantes são voltados para frente) Vem 2 controles remotos  A tv realmente é formidável, valeu muito a pena ter comprado TCL.',
#  'Melhor do que imaginava. Superou minhas expectativas.',
#  'Super leve, prático, fácil manuseio, perfeito p mim.',
#  'Só tenho que agradecer por vocês estão de parabéns',
#  'Eu não recebi o produto e a americanas sabe disso pois já relatei a reclamação diversas vezes!!! Só vão devolver o dinheiro no procon e isso mesmo?????',
#  'Ótimo produto, comprei para uma pessoa albina, ele adorou super leve o tecido.',
#  'Pra quem gosta de qualidade com um preço acessível a todos, eis a melhor opção.',
#  'Gostaria de cancelar esta compra, peço sua gentileza me informar como devo proceder.',
#  'Uma tela impecável. Se sua prioridade é tela e câmera, esse é o cara. O ponto fraco fica por conta do armazenamento, apenas 16GB, e pela câmera frontal, de apenas 5Mpixels sem flash. No entanto, a câmera principal de 13Mpixels é perfeita.',
#  'Aparelho condiz com a sua descrição, super top, tenho o zen fone 3 é comprei este para minha esposa, ela está amando, super recomendo.',
#  'Não recebi segundo o correio o endereço  estava errado! Porém o outro pedido recebi!',
#  'Muito bonita e prática. Chegou antes do prazo. Americanas de parabéns.',
#  'Top de linha, vale a pena comprar, gostei e não me arrependo de ter comprado',
#  'Excelente produto...gostei mesmo... Excelente produto...gostei mesmo...',
#  'Excelente produto...gostei mesmo... Excelente produto...gostei mesmo...',
#  'Melhor custo benefício. Exatamente  como anunciado. Recomendo .',
#  'sim e um bom produto pode comprar sem poblema Gostei muito do produto!',
#  'Gostaria de saber se esse celular tem câmera frontal',
#  'Com exceção que veio a marca Verde ao invés de Jl  Protect,  funciona super bem.  Essas coisas chinesas são bem parecidas mesmo.',
#  'Achei lindo, too de linha,, design lindo, câmera, resposta boa, rápida, preço e prazo ,tudo certinho,,adorei o celular,,parabéns americanas,,,,nota dez,,,,',
#  'Fiquei satisfeito com a segurança e garantia de toda transação, entretanto fiz outra compra no dia 29/11 e até hoje não foi entregue. O que diferencia uma compra da outra com relação a entrega?',
#  'Adorei o produto. É bonito e prático. Recomendo. A entrega foi feita antes do prazo.',
#  'Nao veio esse produto nao chegou entao não tem como eu avalia',
#  'Máscara de cílios incrível, tenho pouquíssimo cílios e ela deu um super efeito! Amei!',
#  'Aparelho de ótima qualidade e sem defeitos, entrega com pontualidade e qualidade !',
#  'O produto chegou no prazo e em ótimo estado, tenho sido muito bem atendida quando solicito algo no site.',
#  'Tem bom acabamento e é pratico. Serviu para o que eu precisava!',
#  'Ótimo equipamento. Som forte, portátil, prático. Uso muito.',
#  'Perfeito, funciona muito bem. Ótimo acabamento. Recomendo',
#  'O produto é  excelência para doméstico quando quer usar você monta e quando não usa você desmonta',
#  'Cabelos alinhados, sem frizz e muito mais rápido do que com escova convencional. Aprovadíssimo.',
#  'A câmera frontal do meu é terrível, tanto faz tá claro ou escuro, a foto fica ruim de qualquer jeito. Muito arrependida!',
#  'Gostei do produto! Valeu a pena a compra. Atendeu ao objetivo para o qual foi adquirido!',
#  'Muito útil, para pesquisas e baixar publicações e vídeos, usando o app jw library.  Parabéns!',
#  'Não recebi o produto e a transportadora colocou que recebi. Preciso receber esse produto.',
#  'Secador bom, mas cumpre o papel de um secador mediano, não tem nada de especial. Não acho que vale o que custa, se eu soubesse teria investido mais em outro melhor ou menos em outro que provavelmente faria a mesma coisa.',
#  'recomendo produto muito bom material de boa qualidade.',
#  'Parece original veio com os lacres e tudo certo.entregou até rápido por ser final de ano.',
#  'Produto funciona corretamente e é muito bom, mas é importante sempre destacar no anúncio que a bateria é de uma boa marca, mas diferente da marca Samsung.',
#  'Produto cumpre o que fala, único porém é que a internet cai um pouco a velocidade',
#  'Minha neta está encantada com a boneca! E a entrega melhor ainda antes do prazo de entrega. Parabéns!',
#  'Claro q eu não esperava um fone maravilhoso, mas o som q vem desse fone é horrível.. Se equipara ao comprado em.camelôs',
#  'Produto atendeu nossa necessidade e a entrega foi excelente.',
#  'Muito bom, com bastante memória, câmera excelente e  outros mais recomendo.',
#  'Ele é bom pra criança, pois tem as teclas pequenas.',
#  'Comprei o produto dia 30/11 até hoje dia 01/01 não chegou!! É uma vergonha, dão um prazo e não cumprir e não adianta falar que é devido ao movimento de final de ano,  pois pedi um outro produto em outro site e em 8 dias estava na minha casa! Não compro mais',
#  'Água gelada à disposição: a turma bebe mais água e isso é ótimo. Aparelho silencioso e bonito, com espaço para acomodar uma jarra. Pode parecer pouca a diferença entre pegar água da geladeira ou do filtro, mas, considerando que na geladeira há outras opções e o bom é beber água, a prática mostrou que vale a pena essa facilidade, e a saúde agradece...',
#  'O produto tem um acabamento regular. A parte final as peças vieram com o corte torto. Vale pelo preço mais acessível se comparado com outros lojas.',
#  'Achei o produto muito inferior  Pois as bonecas tem uma qualidade bem melhor porém esse kit deixou muito a desejar as massinhas são tão pequenas que teria quase que comprar umas 3 de cada pra fazer alguma coisa  Masssss ok',
#  'Adorei a cafeteira.  O encaixe é perfeito e não passa pó para o café  pronto(minha antiga passava)',
#  'Adorei agora faço meus pães em casa com muito mais qualidade e muito mais saudáveis',
#  'A entrega sempre no prazo e muitas vezes até antes. O produto com um custo benefício muito bom. Recomendo tanto o site quanto o produto.',
#  'Resistente, bonita e super espaçosa. Serviu muito bem para o que foi comprada!!!',
#  'O produto é completamente diferente da descrição e da foto. Não recomendo.',
#  'Linda bola de pelúcia, acabamento impecável! Poderiam fazer em um tamanho pequeno também, para bebês. Mas o produto é muito bom.',
#  'Isso e um absurdo ate agora não entregou, comprei pra entregar ate 18:12:2017 e ate hoje não foi entregue , hoje e dia 01:01;2018',
#  'Produto de primeira e o tamanho adequado para 1 a 2 pessoas',
#  'Produto de péssima qualidade quase tudo de papelão não acompanha os carrinhos produto de qualidade inferior. Não comprem não iludam seus filhos. produto lixo',
#  'Muito bom produto excelente,entrega muito rápido recomendadíssimo',
#  'Nunca estive tão esperançoso para receber um produto como este. Porém ainda não se encontra em minha mãos. Portanto prefiro avaliá-lo após sua chegada.  Att.   Amador',
#  'loja ruim cancelou a compra sem solicitaçao de cancelamento e comunicou o cliente',
#  'Recomendo!! Produto original tudo ok! Entregue dentro do prazo prometido.',
#  'Produto com bom shape, resistente e bonito. Truck com qualidade e macio.',
#  'Até hoje não recebí o produto.... não recomendo a loja pra ninguém. Era presente de Natal....péssimo atendimento nenhum esforço dos atendetes para melhorar entrega....tô fora dessa loja.',
#  'Ótimo produto fácil instalação e muito bonita. Moderna',
#  'Pequeno compacto mais muitoooooooo eficiente. Ameiiiiiiii Recomendo',
#  'Ótimo produto, original, recomendo a todos!!! Podem comprar, prazo de entrega dentro do esperado, preço muito atrativo, parabéns as Americanas, farei mais compras futuras.',
#  'Super bonita, potente,  demorou para chegar,  preço otimo,  recomendo',
#  'Muito bom, principalmente o prazo de entrega, a qualidade no envio do produto',
#  'O tapete é suave ao toque, pelos sedosos, a cor mesclada dá um ar maravilhoso ao ambiente.',
#  'Procurei um carrinho com bateria para ficar livre das pilhas. A bateria demora a carregar e dura 5 minutos. O presente de Natal foi uma frustação. Não  recomendo o brinquedo.',
#  'Além de vazar po no café a jarra escurece , péssima qualidade . Tomar café com po na da né',
#  'Produto muito bom. Atende ao que se propõe. Xxxxxxxxxx xxxxccccxxxxx ososoosososososiisisizizizi Ososoosososiz',
#  'A primeira vez de uso quando fui guarda o fone na caixa a espuminha saiu do fone e pra colocar no lugar leva muito tempo',
#  'Recomendo tanto o produto quanto a loja, produto conforme anunciado e entrega antes do prazo previsto...muito bom!!',
#  'Produto ainda não foi entregue, aguardando a transportadora fazer o serviço',
#  'terceiro motorola que tenho e só posso dizer que amoooo',
#  'O produto chegou antes do prazo e é um excelente produto.',
#  'A Barbie é articulada, o cachorro dá alguns passinhos (quando damos corda), e faz cocô quando abaixamos seu rabo. A boneca não fica em pé sozinha.',
#  'Recebemos antes do prazo prometido, o produto estava bem embalado e facil montagem',
#  'Excelente!!! Produto muito bom, bonito, design super moderno. De ótima qualidade! Gostei muito!',
#  'Nao recebi o produto na data marcada. Nao existi um telefone de facil acesso para se informar. E o atendimento ao cliente pelo e-mail é péssimo. Nao tira suas dúvidas.',
#  'Celular de qualidade, como nas especificações, e veio tudo certo no prazo.',
#  'Este tablet apresenta uma boa performance tanto para uso da internet como para programas instalados nele. O tamanho da tela e a qualidade da imagem (resolução) são plenammente satisfatórios para o uso pretendido, ou seja, tem bom custo benefício. Um ponto para melhoria seria aumentar sua memória interna, pois ela é inferior a um outro modelo mais antigo, no entanto, isso pode ser contornado adquirindo cartões de memória (micro SD) pois este aparelho possui uma entrada para isso.',
#  'Não tive problema nenhum de dor, eficiente e prático. Super indico!',
#  'Atendeu as expectativas, manual com informações suficientes para o início do uso, fácil manuseio.',
#  'Lixo , paguei e não recebi .....fora de prazo , ninguém resolve nada .',
#  'O brinquedo é muito bom,porém imaginei que fosse um pouquinho maior.',
#  'PRODUTO DE ÓTIMA QUALIDADE EU RECOMENDO MUITO ESSE CELULAR TEM UM ÓTIMO CUSTO BENEFICIO',
#  'Produto prefeito super bonito e atende todas as necessidades',
#  'Ótima imagem e som, o tamanho dela possibilita instalar em vários ambientes.',
#  'Bla bla bla bla bla bla bla bla bla bla bla bla bla bla bla bla bla bla bla bla bla bla  Compre!',
#  'Ótima entrega. Parabéns às Lojas Americanas por cumprir a entrega.',
#  'Produto muito bom, de ótima qualidade!!!! Recomendo!!!',
#  'Como assim? Comprei e não recebi. Questionei aqui nas lojas americanas, Os Correios registraram como produto entregue e ficou por isso mesmo! Meus protestos! (Mesmo sabendo que tudo será como antes!)  OBS.: NÃO RECOMENDO AS LOJAS AMERICANAS! Grrrrr!',
#  'Monitor top sem duvidas com as cores muito boa varias regulagens de altura angulo monitor bonito base super completa 240hz deixa tudo muito liso',
#  'Produto excelente, ótimas funções, rápido, visual muito agradável.',
#  'O produto é muito ótimo, bem macio extremamente confortável.',
#  'Muito bom, amei. O melhor que não precisa furar parede e fazer aquela sujeira que ninguem gosta.',
#  'Aparelho muito bom, discreto e cumpre a função. Gostei!',
#  'Ótimo produto, muito rápido, fácil uso, muito bonito. ótimas funções.',
#  'Esse livro é perfeito para aqueles que querem encontrar a pessoa certa, ele fala de antes, e durante o noivado, e depois, fala da conquista e tudo mais!',
#  'Gostei muito porque firma bem todas as cordas e não deixa trastejar !',
#  'Ótima, amei mais uma vez Americanas arrasando na entrega. Produto de otima qualidade recomendo muito.',
#  'Para substituição de outros óleos na culinária. Exceto para temperar, nesse caso o melhor é  o azeite de oliva.',
#  'Não tão forte como esperava e já quebrou. Ele veio em uma embalagem meio rudimentar.. não senti muita qualidade.',
#  'Já estão me mandando avaliar um produto que nem recebi, o mesmo já está em atraso e não consigo contato com a americanas.com, quando  ligo o contato é  só  com gravações  e enquanto isso estou aqui a ver navios. Americanas agora vcs me surpreenderam porque isso nunca tinha acontecido antes.',
#  'Excelente, bateria aguenta bastante tempo. Realmente eficiente. Recomendo',
#  'muito bom esse copo vendo meu carro para comprar e não  me arrependo,agora invés de perder tempo no trânsito,desfruto se maravilhosos milk Shakes',
#  'O produto e vendido como suporte universal, no entanto ele é apenas para modelos mais novos de carros. Chegou nem perto de dar certo em meu veículo. Solicitei a devolução do produto a um mês atrás e até o presente momento não recebi o e-mail com as recomendações para devolução.',
#  'As frases do jogo que poderia ser menos vulgar. Só crítico isso no jogo tirando  isso é bem interessante.',
#  'Divertido, prático e fabricado material de qualidade. Porém, soh um adesivo q começou a soltar.',
#  'Tiveram dúvidas na entrega mas, solucionaram rapidamente. O produto chegou conforme o pedido. Meus gatos adoram esta ração e o preço é excelente.',
#  'Produto original, entrega rápida ,eu recomendo  e vou comprar novamente.',
#  'Ótimo produto só que muito difícil de encontrar nas lojas convencionais ,entrega muito rápida',
#  'Ótimo produto!! Recomendo  a todos!! Produto excelente da alta qualidade.',
#  'Excelente produto. Prático, rápido e eficaz. Vale a pena comprar, com certeza',
#  'Apenas uma redomendacao, deverie ser escrito no site de que essa ferramenta nao pode ser utilizada para furar cimento ou concreto porque nao tem a funcao martelo.',
#  'MATERIAL MUITO BOM, ENTREGA FOI ANTES DO PRAZO; COM CUSTO BENEFICIO MUITO BOM.',
#  'Houve atraso na entrega, mas fui prontamente atendida pelos fornecedores e pude retirá-lo nos correios.',
#  'Produto com avaria . Defeito Botão não funciona   Foi pedido devolução  Ainda no aguardo do reembolso do valor....  Falta de respeito com o consumidor',
#  'Bom produto e boa entrega, chegou antes da prazo definido',
#  'Uma maquina recomendado para trabalhos leves. Ajuda bastante no dia-dia e, é ótimo para iniciantes, recomendo.',
#  'estou aguardando a troca do meu produto desde o dia 22//12',
#  'O produto não serve para nada, o motor não tem potência suficiente para cumprir o que promete, a lixa não tira nem a a pele morta. Dinheiro jogado fora. Péssimo!!!!!',
#  'Gostei muito do produtooooooooooooooooooooooooooooooooooooooooooooooo!',
#  'Gostei muito, ponta desliza facilmente pelo papel e a cor é linda.',
#  'PRODUTO DE BOA QUALIDADE,SUPEROU MINHAS EXPECTATIVAS.',
#  'Recomendo muito boa.otima qualidade a chapinha e chegou antes do prazo',
#  'Produto de qualidade. Prático. Para quem precisa se organizar.',
#  'Recomendo, principalmente por ser um aparelho com 128 gb espaçoso por dentro , porém em pequeno volume pra usar no bolso ... Por um  preço bem acessível !!!! Site Seguro Recomendo lojas Americanas.',
#  'O produto cumpre o que promete, uma pena não ter conexão de internet wi-fi.',
#  'Atrasou a entrega e fiquei na mão para dar o presente do meu irmão',
#  'Estava programado para chegar em 23/12 porem ainda não chegou :(',
#  'com esse preço é melhor comprar um ar condicionado vcs sempre erram os preços a não  ser que esse copo é de ouro',
#  'Ótimo para o dia a dia e não fica deslizando da cabeça.',
#  'Ótimo produto, funciona muito bem, eu recomendaria.',
#  'A bateria não está durando tanto... o aparelho é muito grande. poderia continuar com todos os recursos , sendo menor e mais leve. no mais muito bonito e bom.',
#  'Produto muito bom, atendeu minhas expectativas e necessidades.',
#  'O aparelho é ótimo, vem com o adaptador para fones convencionais e um fone com a mesma entrada do carregador. A entrega foi dentro do prazo e não tive problema algum.',
#  'O tamanho foi a única coisa q achei diferente. Muito bom o produto e entrega rápida.',
#  'O produto é resistente. Bem bolado e interessante.',
#  'Jogo muito divertido, chegou tudo certinho e chegou antes do prazo de entrega, gostei muito.',
#  'Perfeito com qualidade e conforto e entrega excelente.',
#  'O produto cumpre com o anunciado. Funciona muito bem embaixo do chuveiro, não machuca a pele',
#  'Excelente produto, fácil instalação. Deixa a água com gosto maravilhoso.',
#  'É um bom produto, mas com pequenos ajustes e mudanças poderia ser excelente. Por exemplo: um banco mais confortável e pedais mais resistentes.',
#  'O tamanho dele é pequeno, mas é muito bom.Seu desempenho  é perfeito. Aconselho a comprar.',
#  'Ótimo custo-benefício recomendo comprar.                                                                    Ok',
#  'Gostei muito dos produtos, guarda roupa grande espaçoso, comoda grande com gavetas enormes que desliza que é uma maravilha, berço cama que ótimo com rodas que pode movimentar de um lado para outro, muito bonito causou todos que estão vindo visitar meu neto gostaram muito do jogo de quarto dele.',
#  '- Produto prático e ocupa pouco espaço, além de poder ser usado com outros produtos da mesma marca ampliando a sua capacidade.',
#  '- Produto prático e ocupa pouco espaço, além de poder ser usado com outros produtos da mesma marca ampliando a sua capacidade.',
#  'Tudo correu bem e chegou antes do prazo!!! Produto funcionou bem',
#  'Produto muito bom, smartphone que cumpre as necessidades. Sem muitas funções, mas com o essencial. Recomendo para quem quer economizar e investir em um produto de qualidade.',
#  'Produto muito bom, smartphone que cumpre as necessidades. Sem muitas funções, mas com o essencial. Recomendo para quem quer economizar e investir em um produto de qualidade.',
#  'O controle remoto da TV Philco Smart TV LED 28" Philco  está sem funcionamento. Precisei acionar uma Reclamação em desfavor da Philco para o envio de um novo controle remoto.',
#  'Dentro do prazo e com sistema de rastreamento online!',
#  'Gostaria de saber como obter uma melhor imagens  , esperava uma qualidade maior de imagens',
#  'O produto atendeu as expectativas.  Até o momento não tive nenhum problema.',
#  'Ótimo custo benefício Americanas arrasando na entrega',
#  'Estou muito decepcionado com esta empresa, pois fiz o pedido dos produtos em 01/12 e ate o momento ainda não chegou. O que aconteceu com o pedido?????? aguardo uma resposta salutar!',
#  'o modelo muito bonito.porem  veio com defeito. vazando agua',
#  'deveria ter uma trava pra o copo, que apenas é so colocar. muito fraco!',
#  'Já  conhecia este tipo de chaleira, comprei a Cadence pois queria preta e apareceu no Facebook a promoção, não  conhecia a marca, já  utilizei e fiquei satisfeita. Espero que a durabilidade seja longa.',
#  'muito bom recomendo, satisfeito com a Tv , chegou no prazo previsto',
#  'Amei a tv digital, uso a noite no meu trabalho atendeu as minhas necessidade , so tenho uma reclamaçao a bateria dura apenas 2:30 h, sendo a partir dai necessario conecta-la a uma fonte de energia..',
#  'Ele e muito bom ,bom, bom , bom , bom. BOM BOM BOM Tao bom ,que fica ruim.',
#  'Um baita descaso, estava programado para chegar no dia 22, pois comprei justamente para presentear no Natal, a empresa demorou vários dias para postar até imagino que vão dizer que a culpa é dos correios, não compro mais da americanas, não recomendo nem pra inimigo! Estou muito insatisfeito!',
#  'Notebbok muito bom! Rápido pequeno e leve para quem quer um notebook com um bom desempenho e que oculpa pouco espaço ele é perfeito. A autonomia da bateria é muito boa. Ele liga e desliga muito rápido.',
#  'Não entregaram o produto e até agora não recebi resposta da restituição do pagamento.  Péssimo para mim e possivelmente para Americanas.',
#  'Muito bom! Produto entregue antes do prazo gostei muito mesmo!',
#  'Produto aparentemente falso de pesima qualidade nunca pensei que uma loja como americanas aceitaria ser comecliza um produto desse não tenho mais coragem de compra perfumes na Americanas',
#  'Campanha ridícula, cheguei ao fim em algumas horas de jogo sem esforço.',
#  'A entrega foi dentro do prazo. Produto atendeu bastante minhas expectativas.',
#  'as borboletas não voam, somente quando colocamos o elefante na horizontal que as borboletas saem.',
#  'Produto muito bom, véi conforme a descrição no anúncio, porém o a demora na postagem foi grande, demorou muito pra chegar.',
#  'Boa tarde. Estou insatisfeita com o aparelho, o mesmo está apresentando problemas na câmera frontal, na verdade a câmera está travada e não há o que fazer.  Quero trocar o produto.',
#  'Produto muito bom, porém a entrega é muito demorada, levaram 2 meses pra entregar, isso é absurdo!!!',
#  'Só o microfone que dá muito ruído...mas o aparelho já tenho igual ...da mesma marca faz mais de três anos sem nenhum defeito e a bateria ainda dura umas três horas...',
#  'Amei ... Excelente compra... Podem comprar ...aprovado... Veio td certinho e completo',
#  'Gostei das tintas são muito boas, vou usa elas agora',
#  'O produto é bom, mas um dos espelhos veio quebrado',
#  'Confio muito nesta marca, porém compro quando está na promoção. Mas é ótima confio de olhos fechados.',
#  'Satisfaz  todas as expectativas, ótimo aparelho, recomendo com certeza.',
#  'Produto nem minha casa chegou, como vou diZer que recomendo ?',
#  'Ótimo custo-benefício, abre todos os programas pesados, rápido e não trava.',
#  'a loja americana estar de entrega antes do prazo produto muito bom recomendo',
#  'A caixa não funciona mais, não recebe carga. Não consigo carregar.',
#  'Minha avaliação é ruim porque ainda não recebi o produto, e também nenhuma explicação sobre qual o problema está aocorrendo.',
#  'Faz pão maravilhosos e bolo também muito eficiente amei!!',
#  'Está atendendo muto bem o produto permitindo uma ótima qualidade de vida e saúde.',
#  'O produto chegou rápido em conformidade e a qualidade é muito boa.',
#  'tinha comprado a outra cozinha com a geladeira e mudarão o produto',
#  'Só poderei avaliar a hora que o produto chegar, o que ainda não aconteceu.',
#  'Muito bom. Entregue no prazo. recomendado para este produto.',
#  'Muito barato.. por esse preço levo os 2 do estoque kkkkkk',
#  'A ASA DO LADO DIREITO QUANDO ACIONADA PULA E SAI DO LUGAR. GOSTARIA DE SABER COMO FAÇO A TROCA OU LEVO EM ALGUM LUGAR PARA OLHAR.',
#  'Eu não recebi a boneca LOL, por isso não tem como avaliá-la',
#  'Ótimo produto!!!!!!!!!! Recomendo a todos os compradores.',
#  'Combinou com as cores do painel do meu carro, show!!',
#  'Não me entregou no prazo previsto.estou aguardando até agora!!pagar 220$ de frete e não chegar no prazo..',
#  'O produto vem uma ótima quantidade,dura por um bom tempo e faz o que promete.',
#  'Não veio na caixa do produto original e veio com uma caixa bem velha e não veio manual. Ainda não testei o produto.',
#  'Chegou antes do prazo... Produto completo em excelentes condições',
#  'Muito bom aparelho e gostei também do tempo para entrega que foi bem rápido.!!',
#  'mudou minha visao sobre o direito atraves de uma leitura simples',
#  'Produto ótimo, vale muito a pena, o ruim foi só a demora pra entregar, tirando isso tudo ok, recomendo.',
#  'O prazo vencerá dia 10/01 e nota  fiscal sequer foi emitida. Estou muito preocupado se vai chegar no prazo.',
#  'O produto tem um tamanho bom que atende a idade de 3 anos. Foi bem embalado, e chegou antes da data prevista',
#  'Muito bom, fácil de mexer e design clean. Super prático.',
#  'Fiquei surpreso com a entrega, foi muito rápido! Também estou satisfeito com o J1 é um celular simples mas cumpre o que promete, é barato e funcional. Foi minha primeira compra no site mas pretendo comprar novamente, recomendo.',
#  'Gostei muito. Recomendo e já vem com bateria. Caso alguém se interesse',
#  'Entrega dentro do prazo.  Produto dentro do esperado.',
#  'Pedimos pelo site e chegou rápido, além do produto ser de ótima qualidade, as coisas ficaram mais rápidas de serem feitas com ela.',
#  'Quando vi essa promoção, vim correndo pois não queria perder a oportunidade.',
#  'Excelente aparelho e a Americanas sempre  de parabéns, entrega antes do previsto.',
#  'Jogo completo e bem bonito. Porém as panelas são pequenas... como na minha casa serão apenas duas pessoas é bem tranquilo! As peças são lindas.',
#  'o produto foi entregue antes do prazo bem embalado e ñ tive nem um problema com a estrutura do produto, ñ precisei contratar montador  e de facil montagem e só presta atenção,goste muito da experiencia da compra e principalmente do produto expectativas alcançadas..compraria novamente.',
#  'Aparelho muito funcional até dar defeito 5 dias após a entrega. 3 usos apenas. Desapontada',
#  'Vem com adaptador? E que geito éo Adaptador  ? O guidão vem completo so no geito de bota na moto com adaptador e tudo ?',
# ...
#  'Um ótimo produto e entregue antes do prazo , sempre compro nas Lojas Americanas , recomento 100%',
#  'Aparelho de desempenho muito bom.. unico problema é que aquece demais !!',
#  'Tudo certo com o produto. Entrega no prazo, produto de boa qualidade.',
#  'Funcionamento simples e de fácil utilização. Bom acabamento, compacto...a caixa em que vem acondicionada a esteira é útil p/ guardá-la após o uso.',
#  'ja tem mais de 30 dias e nada do meu produto chegar.',
#  'Aparelho entregue e funcionando conforme dados do fabricante!! Atendeu otimamente!',
#  'Produto era o esperado, bom, resistente, achei que seria melhor.',
#  'Fico no aguardo do produto, é um absurdo o que vcs estão fazendo.',
#  'Muito bom preço razoavel.muito util no dia a dia..recomendaria a qualquer um comprar',
#  'recebi o produto no prazo e o produto e bom, ...',
#  'Não compraria novamente aqui, pois o prazo de entrega é fossilizante.',
#  'Gostei muito do produto porque atende as necessidades de uma familia grande e não apresenta problemas no uso a que se destina.',
#  'Super satisfeito com o produto e todas as condições periféricas!',
#  'Era o que eu estava aguardando mesmo.Indico e estou bastante satisfeita.',
#  'Boa qualidade e apresentação. Recomendo a todos que optarem pela marca.',
#  'Muito bom mesmo , adorei, chegou no prazo e o atendimento é ótimo , recomendo',
#  'Produto atendeu minhas expectativas. Gostei muito! Também a entrega foi dentro do prazo.',
#  'O produto veio errado o cabo que necessito e de hdmi da tv para o computador',
#  'Gostei muito produto bem apresentavel e de boa qualiadde.',
#  'Adorei o produto, muito bonito, o material é muito bom e chegou bem embalado sem defeito.',
#  'A saída de ar atrás do aspirador deveria ser tampada',
#  'Máquina de fácil operação, silenciosa e de ótima lavação.',
#  'Gostei do produto, porém o site é muito desorganizado, mercadoria não chega no dia previsto, são colocadas informações que não são verdadeiras, entregam para qualquer pessoa que estiver em casa, sem ao menos anotar nome, documento ou qualquer coisa do tipo. Fiquei muito insatisfeita em relação ao atendimento.',
#  'Comprei por causa do tamanho da tela 10.1 polegadas para ler arquivos PDF. Também bacana para ler reportagens e artigos da internet. Pode cansar um puco devido ao peso maior que de um celular. Estou bem satisfeito.',
#  'Produto de Qualidade, com bom preço. Vale a pena a economia',
#  'Produto de Qualidade, com bom preço. Vale a pena a economia',
#  'Eu comprei um sofá da cor MARROM, conforme mostra a figura acima.  No entanto, o produto veio na cor CINZA, o que desatendeu ao meu pedido.  Se eu quisesse produto na cor cinza eu teria pedido,  e  caso vocês não tivessem compraria em outra loja.  Portanto, numa escala de 1 a 5 estrelas, eu avalio em apenas 1, pois houve o descumprimento da oferta, vide art. 35 do Código de Defesa do Consumidor:  CDC - Lei nº 8.078 de 11 de Setembro de 1990 Dispõe sobre a proteção do consumidor e dá outras providências.  Art. 35. Se o fornecedor de produtos ou serviços recusar cumprimento à oferta, apresentação ou publicidade, o consumidor poderá, alternativamente e à sua livre escolha:  I - exigir o cumprimento forçado da obrigação, nos termos da oferta, apresentação ou publicidade;  II - aceitar outro produto ou prestação de serviço equivalente;  III - rescindir o contrato, com direito à restituição de quantia eventualmente antecipada, monetariamente atualizada, e a perdas e danos.',
#  'adorei, um produto de excelente qualidade, a entrega foi muito antes da data prevista, muito bom, foi entregue sem avarias, continuarei comprando no site das Lojas Americanas, pois me da segurança.',
#  'Comprei dos refletores e na primeira semana de uso um deles começou a piscar sem parar uma lampada interna e não para, não sei oque fazer.',
#  'Sem opnião pois ocorreu tudo conforme informado na hora da compra, produto bom, entrega no tempo informado.',
#  'Vi os pratos na loja física e gostei muito, mas só vendiam individual, resolvi então comprar o conjunto de 24 pratos na loja online, porém eles vieram todos irregulares, com as bordas do prato maiores de um lado e menores do outro.',
#  'Antes de mais nada a loja forneceu uma alternativa logo de cara pela falta de produto anunciado no estoque, já começa daí. Depois as funcionalidades que o produto oferece supera as expectativas, principalmente com relação a backup. O suporte técnico é eficiente!',
#  'Produto ótimo,e a entrega ocorreu antes do prazo,fiquei muito satisfeita com o atendimento,amei.',
#  'Entrega excelente bem antes do previsto, só que em um deles a pintura estava descascada... e com sinais de tinta escorrendo. Mas no mais gostei muito...',
#  'Lindos e modernos, chegou no prazo!  Super recomendo',
#  'Veio com a embalagem toda rasgada e a boneca pequena veio jogadas junto com uma das grandes, e a embalagem da pequena rasgada, uma vergonha, não recomendo',
#  'O produto é de boa qualidade, porém veio faltando uma peça que impossibilita o carro virar para a direita ou para esquerda através do controle, permitindo apenas que o carro vá para frente e para trás. Além disso, a descrição do produto dizia que as portas abriam e o carro que recebi tem portas fixas. Já relatei o problema a loja e estou aguardando uma solução. Se eu receber a peça faço uma nova avaliação.',
#  'otimo gostei muito alem de muito mais carga, recomendo',
#  'Fácil instalação, vem completo (até fita veda rosca vem), fluxo de agua bom.',
#  'Produto de boa qualidade, tamanho ideal para pequenos espaços e super útil.',
#  'estou muito chateada o produto ainda não foi entregue.',
#  'O k10 é um smartphone de otima qualidade e um desaine muito lindo.NOTA 10 PRO K10                  NAO tenho naada para opinar de ruim sobre o k10 so coisas boas.......................',
#  'Muito bom, pratico e eficiente. Estava precisando de um aparador de pelos e como já vi que alguns amigos tinham este, decidi comprá-lo, mais que recomendo!',
#  'ASUS surpreendeu pela câmera de alta resolução que embeleza, os níveis de segurança permissionados e os apps de proteção e melhoria do aparelho. Estou adorando!',
#  'TV show de bola! Tem aplicativos para entrada no YOUTUBE e TWITTER automáticos e muito bons. Só faltou mesmo o aplicativo para NETFLIX, que fez muita falta.',
#  'Primeiro. Venderam um produto que não tinha no estoque.  Segundo.  Solicitei  o cancelamento.  Terceiro  Não cancelaram e ainda tive que pagar pelo cartão de crédito.',
#  'Produto bom entrega rápida gostei e recomendo se possível comprarei mais vezes com vocês.',
#  'Recebi no prazo prometido. Muito bem embalado Muito satisfeito com o atendimento compraxembalagemxentrega.',
#  'Produto apresentou problema no primeiro dia de uso.',
#  'Produto correspondeu as expectativas. Chegou no tempo certo.',
#  'Os talheres são bem bonitos, com um desenho elegante e peso interessante. Não é tão leve como alguns mais baratos. A única ressalva é quanto ao acabamento de algumas peças, pois achei que poderia ser ainda melhor. Mas vale muito a pena. Ótimo custo-benefício.',
#  'Bom produto, rápido, se encaixa bem na mão. Bem funcional.',
#  'PRODUTO BOM. FICOU NA CHUVA E SOL POR DIAS E CONTINUA FUNCIONANDO. CONTROLE REMOTO TEM BOA  SENSIBILIDADE, APROXIMADAMENTE 10M. RECOMENDO.',
#  'Sucesso absoluto nos presentes de natal, todos que receberam gostaram, muito original.',
#  'Gostei muito do produto, porém ele chegou com o vidro da câmera quebrada, já enviei e-mail para a americanas mais eles não respondem. Estou MT chateada, pois comprei para dar de presente e quando a pessoa abriu o vidro estava quebrado.',
#  'Comprei de presente de natal para minha namorada, a previsão de entrega era para o dia 27, mas dia 20 já estava em minhas mãos. Ela ficou super satisfeita com o produto!',
#  'No descritivo estava Technos conct, na compra dava a entender que era outro tipo de relógio. Não recomendaria a compra do produto!',
#  'O produto é  ótimo,  mas a loja não  é  mais,  quem ler essa avaliação  recomendo procurar outra loja pra comprar, não  respeitaram  os prazos de entrega, demora de um mês  pra chegar!!!!',
#  'Produto veio todo arranhado parecendo que é usado.',
#  'Rápido e eficiente! Me atendeu perfeitamente. Chegou no prazo.',
#  'Atingiu minha expectativa , cumpre o que promete, nao e de dificil aplicacao e ja mostra resultado na primeira utilizacao.',
#  'Fiquei satisfeita com o produto, porém o que  me desagradou foi a capa do livro não ser dura e as paginas parecerem jornal, por ser fina e asperosa.',
#  'Estou gostando muito do aparelho, até o momento consegue atender todas as minhas necessidades.',
#  'Bom brinquedo. As crianças que gostam de massinha gostam.',
#  'muito bom mesmo é excelente valeu a pena dar esse presente para meu filho nota 10',
#  'Bom produto, porém o toque é muito baixo e não encontrei controle para aumentar o som.',
#  'Ótimo produto, bonito, leve, boa definição, instalei windows 10, equipamento para estudo e lazer, atende minhas necessidades, estou satisfeito com a compra, bem embalado, entrega no prazo.',
#  'Funcional e num preço justo. Recomendo!          Comprem sem medo!',
#  ...]

# %%
# Remove os Emojis
def _remove_emoji(string):
    emoji_pattern = re.compile("["
                u"\U0001F600-\U0001F64F"  # emoticons
                u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                u"\U0001F680-\U0001F6FF"  # transport & map symbols
                u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                u"\U00002702-\U000027B0"
                u"\U000024C2-\U0001F251"
                u"\U0001f926-\U0001f937"
                u'\U00010000-\U0010ffff'
                u"\u200d"
                u"\u2640-\u2642"
                u"\u2600-\u2B55"
                u"\u23cf"
                u"\u23e9"
                u"\u231a"
                u"\u3030"
                u"\ufe0f"
                "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
def _sub_char_especial_normal(text):
    # Substitui caracteres especiais por letras com acentos

    # Letra minúsculas
    text = re.sub(r"&aacute;", "á", text)
    text = re.sub(r"&atilde;", "ã", text)
    text = re.sub(r"&agrave;", "à", text)
    text = re.sub(r"&acirc;", "â", text)
    text = re.sub(r"&aring;", "a", text)
    text = re.sub(r"&auml;", "a", text)
    text = re.sub(r"&aelig;", "ae", text)
    text = re.sub(r"&eacute;", "é", text)
    text = re.sub(r"&ecirc;", "ê", text)
    text = re.sub(r"&egrave;", "è", text)
    text = re.sub(r"&euml;", "e", text)
    text = re.sub(r"&iacute;", "í", text)
    text = re.sub(r"&icirc;", "î", text)
    text = re.sub(r"&iuml;", "i", text)
    text = re.sub(r"&oacute;", "ó", text)
    text = re.sub(r"&otilde;", "õ", text)
    text = re.sub(r"&ocirc;", "ô", text)
    text = re.sub(r"&ograve;", "ò", text)
    text = re.sub(r"&uacute;", "ú", text)
    text = re.sub(r"&ucirc;", "û", text)
    text = re.sub(r"&ugrave;", "ù", text)
    text = re.sub(r"&uuml;", "u", text)
    text = re.sub(r"&ccedil;", "ç", text)
    text = re.sub(r"&ntilde;", "não", text)

    # Letras maiúsculas
    text = re.sub(r"&Aacute;", "Á", text)
    text = re.sub(r"&Atilde;","Ã", text) # Letra maiúscula
    text = re.sub(r"&Agrave;", "À", text)
    text = re.sub(r"&Acirc;", "Â", text)
    text = re.sub(r"&Aring;", "A", text)
    text = re.sub(r"&Auml;", "A", text)
    text = re.sub(r"&Aelig;", "AE", text)
    text = re.sub(r"&Eacute;", "É", text)
    text = re.sub(r"&Ecirc;", "Ê", text)
    text = re.sub(r"&Egrave;", "È", text)
    text = re.sub(r"&Euml;", "E", text)
    text = re.sub(r"&Iacute;", "Í", text)
    text = re.sub(r"&Icirc;", "Î", text)
    text = re.sub(r"&Iuml;", "I", text)
    text = re.sub(r"&Oacute;", "Ó", text)
    text = re.sub(r"&Otilde;", "Õ", text)
    text = re.sub(r"&Ocirc;", "Ô", text)
    text = re.sub(r"&Ograve;", "Ò", text)
    text = re.sub(r"&Uacute;", "Ú", text)
    text = re.sub(r"&Ucirc;", "Û", text)
    text = re.sub(r"&Ugrave;", "Ù", text)
    text = re.sub(r"&Uuml;", "U", text)
    text = re.sub(r"&Ccedil;", "Ç", text)
    text = re.sub(r"&Ntilde;", "Não", text)
    text = re.sub(r"&Yacute;", "Y", text)

    #any special char to be replaced
    text = re.sub(r"&lt;", "<", text)
    text = re.sub(r"&gt;", ">", text)
    text = re.sub(r"&amp;", "&", text)
    text = re.sub(r"&reg;", "&", text) 
    text = re.sub(r"&copy;", "&", text) 
    text = re.sub(r"&quot;","'", text)
    text = re.sub(r"&lsquo;","'", text)
    text = re.sub(r"&rsquo;","'", text)
    return text

# %%
# Termos em code HTML
def _remove_char_html(text):
    text = re.sub(r"&ndash;","", text)
    text = re.sub(r"&ordf;","", text)
    text = re.sub(r"&nbsp;","", text)
    text = re.sub(r"&cent;","", text)
    text = re.sub(r"&pound;","", text)
    text = re.sub(r"&sect;","", text)
    text = re.sub(r"&copy;","", text)
    text = re.sub(r"&laquo;","", text)
    text = re.sub(r"&raquo;","", text)
    text = re.sub(r"&reg;","", text)
    text = re.sub(r"&deg;","", text)
    text = re.sub(r"&plusmn;","", text)
    text = re.sub(r"&para;","", text)
    text = re.sub(r"&middot;","", text)
    text = re.sub(r"&frac12;","", text)
    text = re.sub(r"&mdash;","", text)
    text = re.sub(r"&lsquo;","", text)
    text = re.sub(r"&rsquo;","", text)
    text = re.sub(r"&sbquo;","", text)
    text = re.sub(r"&ldquo;","", text)
    text = re.sub(r"&rdquo;","", text)
    text = re.sub(r"&bdquo;","", text)
    text = re.sub(r"&dagger;","", text)
    text = re.sub(r"&Dagger;","", text)
    text = re.sub(r"&bull;","", text)
    text = re.sub(r"&hellip;","", text)
    text = re.sub(r"&prime;","", text)
    text = re.sub(r"&Prime;","", text)
    text = re.sub(r"&euro;","", text)
    text = re.sub(r"&trade;","", text)
    text = re.sub(r"&asymp;","", text)
    text = re.sub(r"&ne;","", text)
    text = re.sub(r"&le;","", text)
    text = re.sub(r"&ge;","", text)
    text = re.sub(r"&lt;","", text)
    text = re.sub(r"&gt;","", text)
    return text

# %%
# Remove as tags de HTML
def _remove_tags_html(text):
    text = re.sub('<[^<]+?>', '', str(text))
    return text

# %%
# Remove web sites:
def _remove_web(text):
    text = re.sub(r"(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]|\(([^\s()<>]|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'\".,<>?]))",
                "xxxWEBxxx",
                str(text)
            )
    text = ' '.join([w for w in text.split() if '.com' not in w])
    return text

# %%
# Remove números
def _remove_numbers(text):
    text = re.sub(r'[0-9]+', '', text)
    return text

def _remove_pontuação(text):
    text = re.sub(r'[^\w\s]','',text)
    return text

# %%
def transform_text(text):
    text = _remove_tags_html(text)
    text = _remove_web(text)
    text = _remove_emoji(text)
    text = _sub_char_especial_normal(text)
    text = _remove_char_html(text)
    text = _remove_numbers(text)
    text = _remove_pontuação(text)
    return text

# %%
teste = str(df_filtrado_2['review_text'].sample().tolist())
teste
# Out:
# "['Bom gostaria de relatar minha opinião para quem deseja comprar este produto! Pelo preço não compensa. Tenho ele faz 1 mês, e Não esfria como eu esperava, é um pouco melhor que o ventilador. Se você deseja comprar pra esfriar o ambiente do quarto por exemplo, compre um ar-condicionado, porque este produto não esfria, se for ambiente de sala, é bacana.']"

# %%
transform_text(teste)
# Out:
# 'Bom gostaria de relatar minha opinião para quem deseja comprar este produto Pelo preço não compensa Tenho ele faz  mês e Não esfria como eu esperava é um pouco melhor que o ventilador Se você deseja comprar pra esfriar o ambiente do quarto por exemplo compre um arcondicionado porque este produto não esfria se for ambiente de sala é bacana'

# %%
df_filtrado_2['review_text'] = df_filtrado_2['review_text'].apply(str)
df_filtrado_2['review_text'] = df_filtrado_2['review_text'].apply(transform_text)
# Out:
# C:\Users\kayss\AppData\Local\Temp\ipykernel_4188\1040504740.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado_2['review_text'] = df_filtrado_2['review_text'].apply(str)
# C:\Users\kayss\AppData\Local\Temp\ipykernel_4188\1040504740.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado_2['review_text'] = df_filtrado_2['review_text'].apply(transform_text)

# %% [markdown]
# ## 2.3 Aplicando dicionário na label

# %%
df_filtrado_2['recommend_to_a_friend'].value_counts()
# Out:
# Yes    95066
# No     34014
# Name: recommend_to_a_friend, dtype: int64

# %%
dicionario = {
    'Yes': 1,
    'No' : 0
}

df_filtrado_2['recommend_to_a_friend_num'] = df_filtrado_2['recommend_to_a_friend'].map(dicionario)
# Out:
# C:\Users\kayss\AppData\Local\Temp\ipykernel_4188\45278559.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado_2['recommend_to_a_friend_num'] = df_filtrado_2['recommend_to_a_friend'].map(dicionario)

# %%
df_filtrado_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129080 entries, 0 to 132372
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   recommend_to_a_friend      129080 non-null  object
#  1   review_text                129080 non-null  object
#  2   recommend_to_a_friend_num  129080 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 3.9+ MB

# %%
path_save = r'D:\projetos\Projetos_NLP\text_classifier\data\interim\20220203_notebook0.0_data_filter.csv'
df_filtrado_2.to_csv(path_save)
